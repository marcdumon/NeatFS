# %% [markdown]
# # Tests

# %%
from pathlib import Path
from neat_fs import scan_files

# %%
path = Path('/mnt/Backup/backintime/')
files = scan_files.walk_directory_tree(path)

# %%
files
# Out:
#                                                      path  \
# 0       /mnt/Backup/backintime/AI-PC/root/1/20251001-1...
# 1       /mnt/Backup/backintime/AI-PC/root/1/20251001-1...
# 2       /mnt/Backup/backintime/AI-PC/root/1/20251001-1...
# 3       /mnt/Backup/backintime/AI-PC/root/1/20251001-1...
# 4       /mnt/Backup/backintime/AI-PC/root/1/20251001-2...
# ...                                                   ...
# 639360  /mnt/Backup/backintime/AI-PC/root/1/20251001-1...
# 639361  /mnt/Backup/backintime/AI-PC/root/1/20251001-1...
# 639362  /mnt/Backup/backintime/AI-PC/root/1/20251001-1...
# 639363  /mnt/Backup/backintime/AI-PC/root/1/20251001-1...
# 639364  /mnt/Backup/backintime/AI-PC/root/1/20251001-1...
#
#                         name              stem suffix  \
# 0       takesnapshot.log.bz2  takesnapshot.log   .bz2
# 1               fileinfo.bz2          fileinfo   .bz2
# 2                       info              info
# 3                     config            config
# ...
